# %% [markdown]
# # iPhone 17 YouTube Comments - Data Preprocessing
#
# This notebook contains data preprocessing and analysis for iPhone 17 YouTube comments.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# %% [markdown]
# ## 2. Load Data

# %%
# Load the CSV file
df = pd.read_csv('../iphone17.csv')
print(f"Dataset loaded successfully!")
print(f"Shape: {df.shape}")
# Out:
# Dataset loaded successfully!
# Shape: (4475, 9)

# %% [markdown]
# ## 3. Initial Data Exploration

# %%
# Display first few rows
df.head()
# Out:
#                    comment_id                 author  \
# 0  UgxyC4PT7XLSPoCjmzF4AaABAg  @pitchagoncholrat3974
# 1  UgxHnAImYuYp8WxcFAx4AaABAg            @itsall_btn
# 2  Ugx46VmkD3bPnPWA6Q14AaABAg              @finnewar
# 3  UgzUSDtSvdHAZQwaZQh4AaABAg        @LucaRogers-i6f
# 4  UgwN8NptVI2Dv7SItYJ4AaABAg         @Nordic-vibeer
#
#                                                                                                   text  \
# 0  Can you tell me is the film that cover speaker and phone edge important? Can it make your phone ...
# 1                                                                  Got the cosmic orange one... ssssss
# 2                                                                        I will buy iPhone 15 over 17.
# 3                                                                               i am saving up for one
# 4                                          i still use an iphone 11 but apart from the lag its not bad
#
#           time   time_parsed  likes  is_reply  parent_id           scraped_at
# 0  7 hours ago  1.772614e+09      0     False        NaN  2026-03-04 21:22:31
# 1   3 days ago  1.772380e+09      0     False        NaN  2026-03-04 21:22:31
# 2   4 days ago  1.772294e+09      0     False        NaN  2026-03-04 21:22:31
# 3   4 days ago  1.772294e+09      0     False        NaN  2026-03-04 21:22:31
# 4   4 days ago  1.772294e+09      0     False        NaN  2026-03-04 21:22:31

# %%
# Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4475 entries, 0 to 4474
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   comment_id   4475 non-null   object
#  1   author       4475 non-null   object
#  2   text         4475 non-null   object
#  3   time         4475 non-null   object
#  4   time_parsed  4475 non-null   float64
#  5   likes        4475 non-null   int64
#  6   is_reply     4475 non-null   bool
#  7   parent_id    0 non-null      float64
#  8   scraped_at   4475 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 284.2+ KB

# %%
# Statistical summary
df.describe()
# Out:
#         time_parsed        likes  parent_id
# count  4.475000e+03  4475.000000        0.0
# mean   1.760818e+09     5.534078        NaN
# std    3.465429e+06   102.183473        NaN
# min    1.759593e+09     0.000000        NaN
# 25%    1.759593e+09     0.000000        NaN
# 50%    1.759593e+09     0.000000        NaN
# 75%    1.759593e+09     0.000000        NaN
# max    1.772640e+09  5400.000000        NaN

# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())
print(f"\nTotal missing values: {df.isnull().sum().sum()}")
# Out:
# Missing Values:
# comment_id        0
# author            0
# text              0
# time              0
# time_parsed       0
# likes             0
# is_reply          0
# parent_id      4475
# scraped_at        0
# dtype: int64
#
# Total missing values: 4475

# %%
# Check for duplicate comments
duplicates = df.duplicated(subset=['text']).sum()
print(f"Duplicate comments: {duplicates}")

duplicate_ids = df.duplicated(subset=['comment_id']).sum()
print(f"Duplicate comment IDs: {duplicate_ids}")
# Out:
# Duplicate comments: 116
# Duplicate comment IDs: 0

# %% [markdown]
# ## 4. Basic Statistics

# %%
print("=" * 70)
print("DATASET STATISTICS")
print("=" * 70)
print(f"Total Comments: {len(df)}")
print(f"Top-level Comments: {len(df[df['is_reply'] == False])}")
print(f"Replies: {len(df[df['is_reply'] == True])}")
print(f"Unique Authors: {df['author'].nunique()}")
print(f"Total Likes: {df['likes'].sum()}")
print(f"Average Likes: {df['likes'].mean():.2f}")
print(f"Median Likes: {df['likes'].median():.2f}")
print(f"Max Likes: {df['likes'].max()}")
print("=" * 70)
# Out:
# ======================================================================
# DATASET STATISTICS
# ======================================================================
# Total Comments: 4475
# Top-level Comments: 3505
# Replies: 970
# Unique Authors: 4129
# Total Likes: 24765
# Average Likes: 5.53
# Median Likes: 0.00
# Max Likes: 5400
# ======================================================================

# %% [markdown]
# ## 5. Data Cleaning

# %%
# Remove duplicates if any
df_clean = df.drop_duplicates(subset=['comment_id'])
print(f"Removed {len(df) - len(df_clean)} duplicate comment IDs")

# Remove rows with missing text
df_clean = df_clean[df_clean['text'].notna()]
df_clean = df_clean[df_clean['text'].str.strip() != '']
print(f"Shape after cleaning: {df_clean.shape}")
# Out:
# Removed 0 duplicate comment IDs
# Shape after cleaning: (4475, 9)

# %% [markdown]
# ## 6. Text Preprocessing

# %%
# Add text length column
df_clean['text_length'] = df_clean['text'].str.len()
df_clean['word_count'] = df_clean['text'].str.split().str.len()

print(f"Average text length: {df_clean['text_length'].mean():.2f} characters")
print(f"Average word count: {df_clean['word_count'].mean():.2f} words")
# Out:
# Average text length: 97.16 characters
# Average word count: 18.56 words

# %%
# Create a cleaned text column
def clean_text(text):
    if pd.isna(text):
        return ''
    # Convert to lowercase
    text = str(text).lower()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove mentions and hashtags
    text = re.sub(r'@\w+|#\w+', '', text)
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

df_clean['text_cleaned'] = df_clean['text'].apply(clean_text)
print("Text cleaning completed!")
# Out:
# Text cleaning completed!

# %% [markdown]
# ## 7. Visualizations

# %%
# Likes distribution
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Histogram
axes[0].hist(df_clean['likes'], bins=50, edgecolor='black')
axes[0].set_xlabel('Likes')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Distribution of Likes')
axes[0].grid(True, alpha=0.3)

# Box plot
axes[1].boxplot(df_clean['likes'])
axes[1].set_ylabel('Likes')
axes[1].set_title('Box Plot of Likes')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Top-level comments vs Replies
reply_counts = df_clean['is_reply'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(reply_counts.values, labels=['Top-level', 'Replies'], autopct='%1.1f%%', startangle=90)
plt.title('Top-level Comments vs Replies')
plt.show()

# %%
# Text length distribution
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].hist(df_clean['text_length'], bins=50, edgecolor='black')
axes[0].set_xlabel('Text Length (characters)')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Distribution of Text Length')
axes[0].grid(True, alpha=0.3)

axes[1].hist(df_clean['word_count'], bins=50, edgecolor='black', color='orange')
axes[1].set_xlabel('Word Count')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Distribution of Word Count')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Top authors by comment count
top_authors = df_clean['author'].value_counts().head(10)

plt.figure(figsize=(12, 6))
top_authors.plot(kind='barh')
plt.xlabel('Number of Comments')
plt.ylabel('Author')
plt.title('Top 10 Most Active Commenters')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Top liked comments
top_liked = df_clean.nlargest(10, 'likes')[['author', 'text', 'likes']]
print("Top 10 Most Liked Comments:")
print("=" * 100)
for idx, row in top_liked.iterrows():
    print(f"\nAuthor: {row['author']}")
    print(f"Likes: {row['likes']}")
    print(f"Comment: {row['text'][:200]}..." if len(row['text']) > 200 else f"Comment: {row['text']}")
    print("-" * 100)
# Out:
# Top 10 Most Liked Comments:
# ====================================================================================================
#
# Author: @Kanishkkulal
# Likes: 5400
# Comment: iPhone 11 users gather up
# ----------------------------------------------------------------------------------------------------
#
# Author: @Annetteechsler
# Likes: 2700
# Comment: Going from a 15 Pro to a 17 Pro, the first thing I noticed was that my battery life increased by more than 50%.  Such a massive improvement in itself.
# ----------------------------------------------------------------------------------------------------
#
# Author: @mich977f
# Likes: 2100
# Comment: When you switch from "Shot on iPhone" to "Shot on iPhone (ProRes RAW)", before I heard you said ProRes Raw, I thought it was DSLR and you were gonna say DSLR. That difference between the "normal" shot...
# ----------------------------------------------------------------------------------------------------
#
# Author: @destroyion2443
# Likes: 1300
# Comment: Crazy refresh pull
# ----------------------------------------------------------------------------------------------------
#
# Author: @ZacCollin98
# Likes: 1200
# Comment: Maybe this isnt the best iphone ever but it has a great display and the cameras are actually the best so far, so I'm loving it so much! Now maybe a case, a cool one as a piece de resistánce. any idea ...
# ----------------------------------------------------------------------------------------------------
#
# Author: @pessed778
# Likes: 1000
# Comment: we are being PUMPED with videos this week
# ----------------------------------------------------------------------------------------------------
#
# Author: @pannnaga
# Likes: 563
# Comment: I want a camera comparison between the iPhone 17 lineup and older models like the 13 and 14 Most of us don’t upgrade every year, so comparing only with the previous iPhone doesn’t make much sense to u...
# ----------------------------------------------------------------------------------------------------
#
# Author: @KaranR-v9i
# Likes: 496
# Comment: 2:53 Finally someone called out this annoying flare issue in iPhone videos which all iphone camera review videos always miss.
# ----------------------------------------------------------------------------------------------------
#
# Author: @bananahamock-d3b
# Likes: 480
# Comment: Damn Arun, great video, shoutout to the team and editors!!!
# ----------------------------------------------------------------------------------------------------
#
# Author: @Akashbeckham17
# Likes: 368
# Comment: Clicked so fast that i time traveled few sec back
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 8. Save Preprocessed Data

# %%
# Save cleaned data
output_file = '../iphone17_preprocessed.csv'
df_clean.to_csv(output_file, index=False, encoding='utf-8-sig')
print(f"Preprocessed data saved to: {output_file}")
print(f"Final shape: {df_clean.shape}")
# Out:
# Preprocessed data saved to: ../iphone17_preprocessed.csv
# Final shape: (4475, 12)

# %% [markdown]
# ## 9. Summary

# %%
print("=" * 70)
print("PREPROCESSING SUMMARY")
print("=" * 70)
print(f"Original dataset: {df.shape[0]} rows")
print(f"Cleaned dataset: {df_clean.shape[0]} rows")
print(f"Rows removed: {df.shape[0] - df_clean.shape[0]}")
print(f"Columns: {df_clean.shape[1]}")
print(f"\nNew columns added:")
print("  - text_length")
print("  - word_count")
print("  - text_cleaned")
print("=" * 70)
# Out:
# ======================================================================
# PREPROCESSING SUMMARY
# ======================================================================
# Original dataset: 4475 rows
# Cleaned dataset: 4475 rows
# Rows removed: 0
# Columns: 12
#
# New columns added:
#   - text_length
#   - word_count
#   - text_cleaned
# ======================================================================
