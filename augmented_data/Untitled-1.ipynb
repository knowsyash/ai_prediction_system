# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('iphone15_augmented.csv')

# %%
df.head()
# Out:
#    rating              title  \
# 0       5            Awesome
# 1       5          Fabulous!
# 2       5          Wonderful
# 3       5          Fabulous!
# 4       5  Worth every penny
#
#                                          review_text
# 0  Switch from OnePlus to iPhone I am stunned wit...
# 1  So beautiful, so elegant, just a vowww Akshay ...
# 2  Amezing camera and all over best phone Neeraj ...
# 3  Awesome Thakur Surya Pratap Singh , Hanumana G...
# 4  Awesome photography experience. Battery backup...
