# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('mobile_data.csv')

# %%
df.head()
# Out:
#          date                                                url  \
# 0  2026-01-11  https://www.flipkart.com/apple-iphone-15-black...
# 1  2026-01-11  https://www.flipkart.com/samsung-galaxy-s24-ex...
# 2  2026-01-11  https://www.flipkart.com/oneplus-12-silky-blac...
#
#                                                 name    brand  price  \
# 0                    Apple iPhone 15 (Black, 128 GB)    Apple  59900
# 1  Samsung Galaxy S24 Exynos 5G (Cobalt Violet, 2...  Samsung  55999
# 2     OnePlus 12 (Flowy Emerald, 512 GB) (16 GB RAM)  OnePlus  56699
#
#    original_price  discount  rating  total_ratings  1_star  2_star  3_star  \
# 0           59900         0     4.6        6270746       0       0       0
# 1           55999         0     4.6          68481       0       0       0
# 2           56699         0     4.6          61566       0       0       0
#
#    4_star  5_star  camera_rating  battery_rating  display_rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            3 non-null      object
#  1   url             3 non-null      object
#  2   name            3 non-null      object
#  3   brand           3 non-null      object
#  4   price           3 non-null      int64
#  5   original_price  3 non-null      int64
#  6   discount        3 non-null      int64
#  7   rating          3 non-null      float64
#  8   total_ratings   3 non-null      int64
#  9   1_star          3 non-null      int64
#  10  2_star          3 non-null      int64
#  11  3_star          3 non-null      int64
#  12  4_star          3 non-null      int64
#  13  5_star          3 non-null      int64
#  14  camera_rating   3 non-null      float64
#  15  battery_rating  3 non-null      float64
#  16  display_rating  3 non-null      float64
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#          date                                                url  \
# 0  2026-01-11  https://www.flipkart.com/apple-iphone-15-black...
# 1  2026-01-11  https://www.flipkart.com/samsung-galaxy-s24-ex...
# 2  2026-01-11  https://www.flipkart.com/oneplus-12-silky-blac...
#
#                                                 name    brand  price  \
# 0                    Apple iPhone 15 (Black, 128 GB)    Apple  59900
# 1  Samsung Galaxy S24 Exynos 5G (Cobalt Violet, 2...  Samsung  55999
# 2     OnePlus 12 (Flowy Emerald, 512 GB) (16 GB RAM)  OnePlus  56699
#
#    original_price  discount  rating  total_ratings  1_star  2_star  3_star  \
# 0           59900         0     4.6        6270746       0       0       0
# 1           55999         0     4.6          68481       0       0       0
# 2           56699         0     4.6          61566       0       0       0
#
#    4_star  5_star  camera_rating  battery_rating  display_rating  \
# ...

# %%
# Check star breakdown columns
df[['name', '5_star', '4_star', '3_star', '2_star', '1_star']].head()
# Out:
#                                                 name  5_star  4_star  3_star  \
# 0                    Apple iPhone 15 (Black, 128 GB)       0       0       0
# 1  Samsung Galaxy S24 Exynos 5G (Cobalt Violet, 2...       0       0       0
# 2     OnePlus 12 (Flowy Emerald, 512 GB) (16 GB RAM)       0       0       0
#
#    2_star  1_star
# 0       0       0
# 1       0       0
# 2       0       0
